# %%
# Load in all dependencies and helper functions from the main folder
import sys
sys.path.append('..//')
from utils import *
# Out:
# Using TensorFlow backend.
# GPU availbility: ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
df = pd.read_csv(RAW_PATH + 'participant_characteristics.csv')

# %%
df.shape
# Out:
# (51, 25)

# %%
df.head()
# Out:
#   Participant ID  Participant Log ID       Date Setting  \
# 0           P_01       1491423217564   4/5/2017  Laptop
# 1           P_02       1491487691210   4/6/2017  Laptop
# 2           P_07       1491577862552   4/7/2017  Laptop
# 3           P_14       1491927757191  4/11/2017  Laptop
# 4           P_15       1491933738937  4/11/2017  Laptop
#
#    Display Width (pixels)  Display Height (pixels)  Screen Width (cm)  \
# 0                    1440                      900              33.17
# 1                    1440                      900              33.17
# 2                    1440                      900              33.17
# 3                    1440                      900              33.17
# 4                    1440                      900              33.17
#
#    Screen Height (cm)  Distance From Screen (cm)  \
# 0               20.73                       60.0
# 1               20.73                       55.0
# 2               20.73                        NaN
# ...

# %%
df.columns = [x.replace(" ", "_").lower() for x in df.columns]

# %%
df.head()
# Out:
#   participant_id  participant_log_id       date setting  \
# 0           P_01       1491423217564   4/5/2017  Laptop
# 1           P_02       1491487691210   4/6/2017  Laptop
# 2           P_07       1491577862552   4/7/2017  Laptop
# 3           P_14       1491927757191  4/11/2017  Laptop
# 4           P_15       1491933738937  4/11/2017  Laptop
#
#    display_width_(pixels)  display_height_(pixels)  screen_width_(cm)  \
# 0                    1440                      900              33.17
# 1                    1440                      900              33.17
# 2                    1440                      900              33.17
# 3                    1440                      900              33.17
# 4                    1440                      900              33.17
#
#    screen_height_(cm)  distance_from_screen_(cm)  \
# 0               20.73                       60.0
# 1               20.73                       55.0
# 2               20.73                        NaN
# ...

# %%
df.to_csv(MST_PATH + 'participant_characteristics.csv', index = None)

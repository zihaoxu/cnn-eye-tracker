# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
OPENFACE_DIR = "D:\\david_thesis\\OpenFace_exe\\"
IMG_PATH = "D:\\FramesDataset\\"
DATASET_PATH = "D:\\david_thesis\\0_data_lan\\datasets\\"
RAW_PATH = DATASET_PATH + "raw\\"
MST_PATH = DATASET_PATH + "mst\\"

# %%
p_dict = {}
for p in os.listdir(RAW_PATH + 'facial_landmark'):
    path = RAW_PATH + 'facial_landmark\\' + p + '\\'
    p_dict[p] = [path+c for c in os.listdir(path) if c.count('csv') > 0]

# %%
img_nums = pd.Series([len(p_dict[k]) for k in p_dict.keys()])
print("img_nums",img_nums.describe())
sns.distplot(img_nums)
# Out:
# img_nums count       45.000000
# mean      6434.911111
# std       3712.191388
# min        928.000000
# 25%       4005.000000
# 50%       5297.000000
# 75%       8206.000000
# max      16021.000000
# dtype: float64

# %%
p_dict['P_01']
# Out:
# ['D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000001_00000021.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000001_00000060.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000002_00000063.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000002_00000064.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000002_00000119.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000002_00000120.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000003_00000119.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000003_00000120.csv',
#  'D:\\david_thesis\\0_data_lan\\datasets\\raw\\facial_landmark\\P_01\\frame_00000004_00000135.csv',
# ...

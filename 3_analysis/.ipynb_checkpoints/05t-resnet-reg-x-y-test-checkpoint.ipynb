# %%
# Load in all dependencies and helper functions from the main folder
import sys
sys.path.append('..//')
from utils import *
# Out:
# Using TensorFlow backend.
# GPU availbility: ['/job:localhost/replica:0/task:0/device:GPU:0']

# %% [markdown]
# # Load in validation set

# %%
df = pd.read_csv(MST_PATH + 'df_val.csv')
df.head()
# Out:
#                                                   id   coord_x   coord_y  \
# 0  P_39_||_1492629177607_13_-study-benefits_of_ru...  0.666161  0.506861
# 1  P_39_||_1492629177607_21_-study-educational_ad...  0.806306  0.354572
# 2  P_01_||_1491423217564_18_-study-benefits_of_ru...  0.415638  1.212381
# 3  P_01_||_1491423217564_27_-study-where_to_find_...  0.134066  0.328965
# 4  P_40_||_1492693878775_32_-study-tooth_abscess_...  0.759732  0.269527
#
#                                                 path  sharpness participant  \
# 0  D:\david_thesis\0_data_lan\datasets\mst\stitch...    5.06900        P_39
# 1  D:\david_thesis\0_data_lan\datasets\mst\stitch...    4.69625        P_39
# 2  D:\david_thesis\0_data_lan\datasets\mst\stitch...    3.68775        P_01
# 3  D:\david_thesis\0_data_lan\datasets\mst\stitch...    4.50575        P_01
# 4  D:\david_thesis\0_data_lan\datasets\mst\stitch...    4.46025        P_40
#
#                                                 task  webGazerX  webGazerY
# 0  1492629177607_13_-study-benefits_of_running_wr...   0.563194   0.407778
# 1  1492629177607_21_-study-educational_advantages...   0.959028   0.561111
# 2  1491423217564_18_-study-benefits_of_running_wr...   0.172222   0.398889
# 3  1491423217564_27_-study-where_to_find_morel_mu...   0.179861   0.403333
# 4  1492693878775_32_-study-tooth_abscess_writing....   0.625000   0.304167

# %% [markdown]
# # Load in trained model

# %%
# Define model name
BATCH_SIZE = 64
INIT_LR = 5e-5
model_name = "mobile(mae)_adam_"+str(BATCH_SIZE)+"_"+str(INIT_LR)
base_filepath = MODEL_SAVE_PATH + model_name + ".hdf5"
print(base_filepath)
# Out:
# D:\david_xu_thesis\4_models\0_saved_models\mobile(mae)_adam_64_5e-05.hdf5

# %%
# Loading the best model
model = load_model(base_filepath)

# %%
val_pred_xy = model.predict_generator(batch_generator(df, batch_size=BATCH_SIZE),
                                      steps = len(df) // BATCH_SIZE,
                                      verbose = 1)
# Out:
# 859/859 [==============================] - 32s 37ms/step

# %% [markdown]
# # Model Assessment

# %%
# Append prediction to df_val
df['val_pred_x'] = val_pred_xy[0]
df['val_pred_y'] = val_pred_xy[1]
df['residual_x'] = df['coord_x'] - df['val_pred_x']
df['residual_y'] = df['coord_y'] - df['val_pred_y']

# %%
# MAE in x direction: 0.09869 MAE in y direction: 0.1214
old_x_residual = df['residual_x']
old_y_residual = df['residual_y']
print("MAE in x direction:", round(np.mean(abs(df['residual_x'])),5), \
      "MAE in y direction:",  round(np.mean(abs(df['residual_y'])),5))
# Out:
# MAE in x direction: 0.09869 MAE in y direction: 0.1214

# %%
f, axes = plt.subplots(2,1)
g1 = sns.distplot(df['coord_x'], ax = axes[0])
g1.set(xlim = (-0.2, 2.2))
g2 = sns.distplot(df['coord_y'], ax = axes[1])
g2.set(xlim = (-0.2, 2.2))
# Out:
# [(-0.2, 2.2)]

# %%
plt.scatter(df['coord_x'], df['coord_y'], s = 1, alpha = 0.2, label = 'true')
plt.scatter(df['val_pred_x'], df['val_pred_y'], s = 1, c = 'r', alpha = 0.2, label = 'pred')
plt.legend()

# %%
bins = np.arange(-1, 1, 0.05)
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.hist, "residual_x", bins=bins)

# %%
bins = np.arange(-1, 1, 0.05)
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.hist, "residual_y", bins=bins)

# %%
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.scatter, "val_pred_x", "coord_x", s = 1, alpha = .2)

# %%
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.scatter, "val_pred_y", "coord_y", s = 1, alpha = .2)

# %% [markdown]
# # Clip the prediction and actual values

# %% [markdown]
# If we bound the values to all 0 and 1 in both x and y directions, we observe a significant increase in performance in the y-direction.

# %%
# MAE in x direction: 0.0981 MAE in y direction: 0.11214
df['coord_x'] = np.clip(df['coord_x'], 0, 1)
df['coord_y'] = np.clip(df['coord_y'], 0, 1)
df['val_pred_x'] = np.clip(df['val_pred_x'], 0, 1)
df['val_pred_y'] = np.clip(df['val_pred_y'], 0, 1)
df['residual_x'] = df['coord_x'] - df['val_pred_x']
df['residual_y'] = df['coord_y'] - df['val_pred_y']
print("MAE in x direction:", round(np.mean(abs(df['residual_x'])),5), \
      "MAE in y direction:",  round(np.mean(abs(df['residual_y'])),5))
# Out:
# MAE in x direction: 0.0981 MAE in y direction: 0.11214

# %%
plt.scatter(df['coord_x'], df['coord_y'], s = 1, alpha = 0.2, label = 'true')
plt.scatter(df['val_pred_x'], df['val_pred_y'], s = 1, c = 'r', alpha = 0.2, label = 'pred')
plt.legend()

# %%
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.scatter, "val_pred_x", "coord_x", s = 1, alpha = .2)

# %%
g = sns.FacetGrid(df, col="participant")
g = g.map(plt.scatter, "val_pred_y", "coord_y", s = 1, alpha = .2)

# %%
plt.hist(old_x_residual, label = 'old_x_residual', bins = 50)
plt.hist(df['residual_x'], label = 'new_x_residual', bins = 50)
plt.legend()

# %%
plt.hist(old_y_residual, label = 'old_y_residual', bins = 50)
plt.hist(df['residual_y'], label = 'new_y_residual', bins = 50)
plt.legend()

# %% [markdown]
# # Compare CNN with WebGazer

# %%
df['webGazerX'] = np.clip(df['webGazerX'], 0, 1)
df['webGazerY'] = np.clip(df['webGazerY'], 0, 1)
df['webgazer_residual_x'] = df['coord_x'] - df['webGazerX']
df['webgazer_residual_y'] = df['coord_y'] - df['webGazerY']

# %%
sns.distplot(df['webgazer_residual_x'], bins = 50, label = 'WebGazer')
sns.distplot(df['residual_x'],bins = 50, label = 'CNN')
plt.legend()

# %%
sns.distplot(df['webgazer_residual_y'], bins = 50, label = 'WebGazer')
sns.distplot(df['residual_y'],bins = 50, label = 'CNN')
plt.legend()

# %%
# Define a single metric for both models:
df['webGazer_score'] = (df['webgazer_residual_x']**2 + df['webgazer_residual_y']**2)**0.5
df['CNN_score'] = (df['residual_x']**2 + df['residual_y']**2)**0.5

# %%
sns.distplot(df['webGazer_score'], bins = 50, label = 'WebGazer')
sns.distplot(df['CNN_score'],bins = 50, label = 'CNN')
plt.legend()

# %%
np.mean(df['CNN_score'] < df['webGazer_score'])
# Out:
# 0.5725771245634459

# %%
np.mean(df['residual_x'] < df['webgazer_residual_x'])
# Out:
# 0.5499126891734575

# %%
np.mean(df['residual_y'] < df['webgazer_residual_y'])
# Out:
# 0.7650793073341094

# %%
df['cnn_better'] = df['CNN_score'] < df['webGazer_score']
df.groupby('participant').mean()['cnn_better']
# Out:
# participant
# P_01    0.539987
# P_25    0.559628
# P_39    0.692821
# P_40    0.424361
# Name: cnn_better, dtype: float64

# %%
df.groupby('task').mean()['cnn_better']
# Out:
# task
# 1491423217564_18_-study-benefits_of_running_writing.webm_frames                                  0.605737
# 1491423217564_24_-study-educational_advantages_of_social_networking_sites_writing.webm_frames    0.524938
# 1491423217564_27_-study-where_to_find_morel_mushrooms_writing.webm_frames                        0.395112
# 1491423217564_29_-study-where_to_find_morel_mushrooms_writing.webm_frames                        0.494881
# 1491423217564_33_-study-tooth_abscess_writing.webm_frames                                        0.559055
# 1491423217564_35_-study-dot_test_final.webm_frames                                               0.790040
# 1491423217564_3_-study-dot_test.webm_frames                                                      0.323887
# 1492110782158_10_-study-benefits_of_running_writing.webm_frames                                  0.643794
# 1492110782158_14_-study-educational_advantages_of_social_networking_sites_writing.webm_frames    0.479713
# 1492110782158_17_-study-where_to_find_morel_mushrooms_writing.webm_frames                        0.542408
# 1492110782158_21_-study-tooth_abscess_writing.webm_frames                                        0.593469
# 1492110782158_23_-study-dot_test_final.webm_frames                                               0.639792
# 1492110782158_3_-study-dot_test.webm_frames                                                      0.557987
# 1492629177607_13_-study-benefits_of_running_writing.webm_frames                                  0.688649
# 1492629177607_21_-study-educational_advantages_of_social_networking_sites_writing.webm_frames    0.721320
# 1492629177607_28_-study-where_to_find_morel_mushrooms_writing.webm_frames                        0.654386
# 1492629177607_34_-study-tooth_abscess_writing.webm_frames                                        0.705634
# 1492629177607_3_-study-dot_test.webm_frames                                                      0.480300
# 1492693878775_11_-study-benefits_of_running_writing.webm_frames                                  0.567552
# 1492693878775_21_-study-educational_advantages_of_social_networking_sites_writing.webm_frames    0.360272
# 1492693878775_28_-study-where_to_find_morel_mushrooms_writing.webm_frames                        0.311834
# 1492693878775_32_-study-tooth_abscess_writing.webm_frames                                        0.293420
# 1492693878775_34_-study-dot_test_final.webm_frames                                               1.000000
# 1492693878775_3_-study-dot_test.webm_frames                                                      0.503827
# Name: cnn_better, dtype: float64
